# %%
from main import meta_main, get_args
from tools import plot_entropy, plot_pdf
from os.path import join
import sys

# %% [markdown]
# ### First two experiments for $d=10,64$ in Section 3.1.1

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 1
args.iterations = 200
args.pdf = 'gaussian'
args.dimension = 10
args.reps = 3
args.lr = 1e-2

meta_main(args)
# Out:
# INFO:main:Doing run 1...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       200
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:main:Epoch 1/1 starting ...
# 100%|██████████| 200/200 [00:03<00:00, 59.62it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
#  86%|████████▌ | 171/200 [00:01<00:00, 93.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       8 args.reps = 3
#       9 args.lr = 1e-2
# ---> 11 meta_main(args)
#
# File ~/Desktop/pimms/examples/differential_entropy_estimation/main.py:331, in meta_main(args)
#     329 if args.reps > 1:
#     330     args.run_id = i + 1
# --> 331 outputs = {k: np.array([v]) for k, v in main(args).items()}
#     332 for name, value in outputs.items():
#     333     if name not in all_outputs:
#
# File ~/Desktop/pimms/examples/differential_entropy_estimation/main.py:244, in main(args)
#     242     for i, x in enumerate(tqdm(dataloader)):
#     243         x = _c(x[0])
# --> 244         H_est[i] = model(x).mean().detach().cpu().numpy()
#     245     H_est = H_est.mean()
#     247 logger.info(f"  True Entropy:    {true_entropy:.4f}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/pimms/entropy/knife.py:87, in KNIFE.forward(self, X)
#      86 def forward(self, X: Tensor) -> Tensor:
# ---> 87     y = -self.logpdf(X)
#      88     return torch.mean(y)
#
# File ~/Desktop/pimms/entropy/knife.py:76, in KNIFE.logpdf(self, X)
#      74 # print(f"Marg : {var.min()} | {var.max()} | {var.mean()}")
#      75 if self.tri is not None:
# ---> 76     y = y + torch.squeeze(torch.matmul(torch.tril(self.tri, diagonal=-1), y[:, :, :, None]), 3)
#      77 y = torch.sum(y ** 2, dim=2)
#      79 y = -y / 2 + torch.sum(torch.log(torch.abs(var) + 1e-8), dim=-1) + w
#
# KeyboardInterrupt:

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 1
args.iterations = 200
args.pdf = 'gaussian'
args.dimension = 64
args.reps = 3
args.lr = 1e-2

meta_main(args)

# %% [markdown]
# ### Experiment depicted in Figure 1

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 16 #128
args.epochs = 5
args.iterations = 1000
args.pdf = 'gaussian'
args.dimension = 16 #64
args.rho = 0.5
args.rho_steps = 5
args.reps = 1
args.lr = 1e-2
args.run_id = 1

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
# Out:
# INFO:main:Doing run 1...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-16/rho-0.50
#       run_id:           1
#       batchsize:        128
#       iterations:       1000
#       epochs:           5
#       kernel_samples:   16
#       d:                16
#       pdf:              gaussian
#       rho:              0.50
#       lr:               0.01
#
# INFO:main:Epoch 1/5 starting ...
#  74%|███████▍  | 739/1000 [00:05<00:02, 125.40it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 14>()
#      11 args.lr = 1e-2
#      12 args.run_id = 1
# ---> 14 log_dir = meta_main(args)
#      15 plot_entropy(join(log_dir, '1', 'run.json'), show=True)
#
# File ~/Desktop/pimms/examples/differential_entropy_estimation/main.py:331, in meta_main(args)
#     329 if args.reps > 1:
#     330     args.run_id = i + 1
# --> 331 outputs = {k: np.array([v]) for k, v in main(args).items()}
#     332 for name, value in outputs.items():
#     333     if name not in all_outputs:
#
# File ~/Desktop/pimms/examples/differential_entropy_estimation/main.py:203, in main(args)
#     201 for model, opt, name in zip(models, opts, model_names):
#     202     loss_adaptive = model(x)
# --> 203     loss_adaptive.backward()
#     204     loss_np = loss_adaptive.detach().cpu().numpy()
#     205     error_np = loss_np - true_entropy
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor.py:363, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     354 if has_torch_function_unary(self):
#     355     return handle_torch_function(
#     356         Tensor.backward,
#     357         (self,),
#    (...)
#     361         create_graph=create_graph,
#     362         inputs=inputs)
# --> 363 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Experiment depicted in Figure 2(left)

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 10
args.iterations = 200
args.pdf = 'triangle'
args.dimension = 1
args.plot = True
args.data_components = 10
args.lr = 1e-1
args.run_id = 1

log_dir = meta_main(args)
plot_pdf(join(log_dir, '1', 'pdfs_KNIFE_0.json'), show=True)
# Out:
# INFO:main:Doing run 1...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-1/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       200
#       epochs:           10
#       kernel_samples:   128
#       d:                1
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.10
#       data_components:  10
# INFO:main:Epoch 1/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 80.75it/s]
# INFO:main:Epoch 2/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 84.60it/s]
# INFO:main:Epoch 3/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 79.17it/s]
# INFO:main:Epoch 4/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 77.06it/s]
# INFO:main:Epoch 5/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 80.06it/s]
# INFO:main:Epoch 6/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 75.02it/s]
# INFO:main:Epoch 7/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 82.40it/s]
# INFO:main:Epoch 8/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 74.56it/s]
# INFO:main:Epoch 9/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 80.89it/s]
# INFO:main:Epoch 10/10 starting ...
# 100%|██████████| 200/200 [00:02<00:00, 80.13it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:01<00:00, 103.15it/s]
# INFO:main:  True Entropy:    0.4491
# INFO:main:  Final Estimate:  0.5645
# INFO:main:  ERRROR:          0.1154
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:01<00:00, 104.93it/s]
# INFO:main:  True Entropy:    0.4491
# INFO:main:  Final Estimate:  0.5200
# INFO:main:  ERRROR:          0.0708
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:01<00:00, 126.71it/s]
# INFO:main:  True Entropy:    0.4491
# INFO:main:  Final Estimate:  2.4923
# INFO:main:  ERRROR:          2.0432
# INFO:main:FINAL:
# INFO:main:KNIFE:
# INFO:main:  error 1: 0.1154 ± 0.0000
# INFO:main:Schraudolph:
# INFO:main:  error 1: 0.0708 ± 0.0000
# INFO:main:DoE:
# INFO:main:  error 1: 2.0432 ± 0.0000
# Model KNIFE
# Shape (1000,)
# Model Schraudolph
# Shape (1000,)
# Model DoE
# Shape (1000, 1)

# %% [markdown]
# ### Experiment depicted in Figure 2(right)

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 20
args.iterations = 1000
args.pdf = 'triangle'
args.dimension = 8
args.data_components = 2
args.lr = 1e-3
args.reps = 3

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
# Out:
# INFO:main:Doing run 1...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 108.96it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 110.16it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 99.72it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 101.40it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 99.85it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 107.78it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 104.63it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 105.40it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 106.18it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 103.35it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 105.04it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 103.69it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 100.66it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 94.25it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 104.74it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 101.98it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 107.04it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 102.73it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 101.01it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 102.40it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 285.69it/s]
# INFO:main:  True Entropy:    -12.1776
# INFO:main:  Final Estimate:  -11.7355
# INFO:main:  ERRROR:          0.4421
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 360.38it/s]
# INFO:main:  True Entropy:    -12.1776
# INFO:main:  Final Estimate:  -10.6672
# INFO:main:  ERRROR:          1.5104
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 461.14it/s]
# INFO:main:  True Entropy:    -12.1776
# INFO:main:  Final Estimate:  6.4937
# INFO:main:  ERRROR:          18.6713
# INFO:main:Doing run 2...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 108.90it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 110.09it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 110.22it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 110.11it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 107.60it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 94.59it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 93.77it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 102.06it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 103.06it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 102.03it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 100.71it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 95.52it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 95.88it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 98.05it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 93.19it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:11<00:00, 87.68it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 93.69it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 99.94it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 101.11it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 97.78it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 273.93it/s]
# INFO:main:  True Entropy:    -11.2190
# INFO:main:  Final Estimate:  -10.7732
# INFO:main:  ERRROR:          0.4458
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 348.06it/s]
# INFO:main:  True Entropy:    -11.2190
# INFO:main:  Final Estimate:  -9.8055
# INFO:main:  ERRROR:          1.4135
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 407.18it/s]
# INFO:main:  True Entropy:    -11.2190
# INFO:main:  Final Estimate:  5.9684
# INFO:main:  ERRROR:          17.1874
# INFO:main:Doing run 3...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           3
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 96.65it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 91.11it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 94.13it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 98.27it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 96.99it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 97.90it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 97.86it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 97.94it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:11<00:00, 89.22it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 95.88it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 92.69it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 96.04it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 94.91it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:11<00:00, 86.24it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 91.52it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 93.63it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 92.54it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:10<00:00, 93.61it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 102.64it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 104.53it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 278.10it/s]
# INFO:main:  True Entropy:    -2.5970
# INFO:main:  Final Estimate:  -1.8492
# INFO:main:  ERRROR:          0.7479
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 362.43it/s]
# INFO:main:  True Entropy:    -2.5970
# INFO:main:  Final Estimate:  -0.8966
# INFO:main:  ERRROR:          1.7004
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 458.68it/s]
# INFO:main:  True Entropy:    -2.5970
# INFO:main:  Final Estimate:  6.6092
# INFO:main:  ERRROR:          9.2063
# INFO:main:FINAL:
# INFO:main:KNIFE:
# INFO:main:  error 1: 0.5452 ± 0.1433
# INFO:main:Schraudolph:
# INFO:main:  error 1: 1.5415 ± 0.1192
# INFO:main:DoE:
# INFO:main:  error 1: 15.0217 ± 4.1565

# %% [markdown]
# ### Experiment in supplementary material, B.2

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 20
args.iterations = 1000
args.pdf = 'triangle'
args.dimension = 20
args.data_components = 2
args.lr = 1e-3
args.reps = 2 # 10

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
# Out:
# 100%|██████████| 1000/1000 [00:31<00:00, 32.11it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.24it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.55it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.54it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.48it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.65it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.76it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.71it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.66it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.72it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.58it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.56it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.49it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.47it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.46it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.48it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.39it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.45it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.24it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 104.83it/s]
# INFO:main:  True Entropy:    -24.4569
# INFO:main:  Final Estimate:  -4.0935
# INFO:main:  ERRROR:          20.3634
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 354.80it/s]
# INFO:main:  True Entropy:    -24.4569
# INFO:main:  Final Estimate:  -5.2133
# INFO:main:  ERRROR:          19.2436
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 455.26it/s]
# INFO:main:  True Entropy:    -24.4569
# INFO:main:  Final Estimate:  17.6085
# INFO:main:  ERRROR:          42.0655
# INFO:main:Doing run 2...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.87it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.15it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.96it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.81it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.75it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.86it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.81it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.73it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.69it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.73it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.63it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.62it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.55it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.60it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.47it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.49it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.44it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.37it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.53it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 105.33it/s]
# INFO:main:  True Entropy:    4.5722
# INFO:main:  Final Estimate:  9.1534
# INFO:main:  ERRROR:          4.5812
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 352.55it/s]
# INFO:main:  True Entropy:    4.5722
# INFO:main:  Final Estimate:  11.7284
# INFO:main:  ERRROR:          7.1562
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 457.35it/s]
# INFO:main:  True Entropy:    4.5722
# INFO:main:  Final Estimate:  18.0651
# INFO:main:  ERRROR:          13.4930
# INFO:main:Doing run 3...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           3
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.93it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.05it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.95it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.61it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.63it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.94it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.03it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.18it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.58it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.67it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.32it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.61it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.72it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.47it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.47it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.76it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.72it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.42it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.53it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 107.55it/s]
# INFO:main:  True Entropy:    0.9095
# INFO:main:  Final Estimate:  9.2919
# INFO:main:  ERRROR:          8.3824
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 317.01it/s]
# INFO:main:  True Entropy:    0.9095
# INFO:main:  Final Estimate:  12.1813
# INFO:main:  ERRROR:          11.2718
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 430.34it/s]
# INFO:main:  True Entropy:    0.9095
# INFO:main:  Final Estimate:  18.1402
# INFO:main:  ERRROR:          17.2307
# INFO:main:Doing run 4...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           4
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.97it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.25it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.99it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.88it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.89it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.87it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.05it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.93it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.12it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.97it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.76it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.71it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.50it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.66it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.52it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.65it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.51it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.38it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 104.28it/s]
# INFO:main:  True Entropy:    -9.4954
# INFO:main:  Final Estimate:  -9.0288
# INFO:main:  ERRROR:          0.4666
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 333.01it/s]
# INFO:main:  True Entropy:    -9.4954
# INFO:main:  Final Estimate:  -6.4423
# INFO:main:  ERRROR:          3.0532
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 409.48it/s]
# INFO:main:  True Entropy:    -9.4954
# INFO:main:  Final Estimate:  17.0082
# INFO:main:  ERRROR:          26.5036
# INFO:main:Doing run 5...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           5
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.62it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.17it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.64it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.74it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.69it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.68it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.63it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.64it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.50it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.62it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.64it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.54it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.54it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.63it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.37it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.33it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.49it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.25it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.27it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.33it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 106.00it/s]
# INFO:main:  True Entropy:    -1.3135
# INFO:main:  Final Estimate:  9.7461
# INFO:main:  ERRROR:          11.0597
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 345.79it/s]
# INFO:main:  True Entropy:    -1.3135
# INFO:main:  Final Estimate:  13.1718
# INFO:main:  ERRROR:          14.4854
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 405.10it/s]
# INFO:main:  True Entropy:    -1.3135
# INFO:main:  Final Estimate:  18.1296
# INFO:main:  ERRROR:          19.4432
# INFO:main:Doing run 6...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           6
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.98it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.11it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.07it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.06it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.91it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.00it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.94it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.53it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.65it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.66it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.68it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.52it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.59it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.65it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.06it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.45it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.60it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.87it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.08it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 105.26it/s]
# INFO:main:  True Entropy:    3.9898
# INFO:main:  Final Estimate:  14.2526
# INFO:main:  ERRROR:          10.2628
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 329.09it/s]
# INFO:main:  True Entropy:    3.9898
# INFO:main:  Final Estimate:  18.8316
# INFO:main:  ERRROR:          14.8418
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 444.55it/s]
# INFO:main:  True Entropy:    3.9898
# INFO:main:  Final Estimate:  18.3563
# INFO:main:  ERRROR:          14.3665
# INFO:main:Doing run 7...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           7
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.08it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.43it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.33it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.30it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.48it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.98it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.94it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.28it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.00it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.47it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.53it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.98it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.47it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.01it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:32<00:00, 30.61it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.02it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.08it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.80it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.75it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 108.43it/s]
# INFO:main:  True Entropy:    1.8354
# INFO:main:  Final Estimate:  8.3434
# INFO:main:  ERRROR:          6.5079
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 330.12it/s]
# INFO:main:  True Entropy:    1.8354
# INFO:main:  Final Estimate:  10.8759
# INFO:main:  ERRROR:          9.0405
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 426.32it/s]
# INFO:main:  True Entropy:    1.8354
# INFO:main:  Final Estimate:  17.9711
# INFO:main:  ERRROR:          16.1357
# INFO:main:Doing run 8...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           8
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.02it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.96it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.63it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.22it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:29<00:00, 33.56it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:29<00:00, 33.35it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.80it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.94it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.80it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.26it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.01it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.22it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.25it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.29it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.00it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.19it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.42it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.53it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.19it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.40it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 106.27it/s]
# INFO:main:  True Entropy:    7.2544
# INFO:main:  Final Estimate:  13.1441
# INFO:main:  ERRROR:          5.8896
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 383.52it/s]
# INFO:main:  True Entropy:    7.2544
# INFO:main:  Final Estimate:  16.5552
# INFO:main:  ERRROR:          9.3007
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 459.00it/s]
# INFO:main:  True Entropy:    7.2544
# INFO:main:  Final Estimate:  18.2189
# INFO:main:  ERRROR:          10.9644
# INFO:main:Doing run 9...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           9
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.03it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.22it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.84it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.88it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.03it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.83it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.60it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.47it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.60it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.55it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.16it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.68it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.71it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.13it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.37it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.11it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.64it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.73it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.82it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.97it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 102.12it/s]
# INFO:main:  True Entropy:    -2.6090
# INFO:main:  Final Estimate:  3.3048
# INFO:main:  ERRROR:          5.9138
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 337.98it/s]
# INFO:main:  True Entropy:    -2.6090
# INFO:main:  Final Estimate:  5.0577
# INFO:main:  ERRROR:          7.6667
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 425.01it/s]
# INFO:main:  True Entropy:    -2.6090
# INFO:main:  Final Estimate:  17.8784
# INFO:main:  ERRROR:          20.4874
# INFO:main:Doing run 10...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           10
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.83it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.03it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.51it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.39it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.87it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.10it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.64it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.37it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.46it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.45it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 32.01it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:29<00:00, 33.42it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.83it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.60it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.80it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.88it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:31<00:00, 31.71it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.52it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.78it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.27it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 107.41it/s]
# INFO:main:  True Entropy:    -11.6993
# INFO:main:  Final Estimate:  0.2543
# INFO:main:  ERRROR:          11.9536
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 393.12it/s]
# INFO:main:  True Entropy:    -11.6993
# INFO:main:  Final Estimate:  1.3377
# INFO:main:  ERRROR:          13.0369
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 478.14it/s]
# INFO:main:  True Entropy:    -11.6993
# INFO:main:  Final Estimate:  17.9284
# INFO:main:  ERRROR:          29.6276
# INFO:main:FINAL:
# INFO:main:KNIFE:
# INFO:main:  error 1: 8.5381 ± 5.0960
# INFO:main:Schraudolph:
# INFO:main:  error 1: 10.9097 ± 4.4133
# INFO:main:DoE:
# INFO:main:  error 1: 21.0317 ± 8.8887
# INFO:main:Doing run 1...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.42it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.77it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.30it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.11it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.88it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.03it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.12it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.06it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.75it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.26it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.82it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.07it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.52it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.33it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.99it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.61it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.83it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.84it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.82it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 106.01it/s]
# INFO:main:  True Entropy:    -2.7253
# INFO:main:  Final Estimate:  10.8261
# INFO:main:  ERRROR:          13.5513
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 362.33it/s]
# INFO:main:  True Entropy:    -2.7253
# INFO:main:  Final Estimate:  14.6901
# INFO:main:  ERRROR:          17.4154
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 449.66it/s]
# INFO:main:  True Entropy:    -2.7253
# INFO:main:  Final Estimate:  18.1797
# INFO:main:  ERRROR:          20.9050
# INFO:main:Doing run 2...
# INFO:main:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-20/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                20
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:main:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.09it/s]
# INFO:main:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.29it/s]
# INFO:main:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.14it/s]
# INFO:main:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.29it/s]
# INFO:main:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.19it/s]
# INFO:main:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.45it/s]
# INFO:main:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.78it/s]
# INFO:main:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.87it/s]
# INFO:main:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.73it/s]
# INFO:main:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 33.03it/s]
# INFO:main:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.69it/s]
# INFO:main:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.64it/s]
# INFO:main:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.85it/s]
# INFO:main:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.56it/s]
# INFO:main:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.91it/s]
# INFO:main:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.61it/s]
# INFO:main:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.54it/s]
# INFO:main:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.32it/s]
# INFO:main:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:30<00:00, 32.65it/s]
# INFO:main:Finished training.
# INFO:main:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 106.23it/s]
# INFO:main:  True Entropy:    5.5635
# INFO:main:  Final Estimate:  14.4922
# INFO:main:  ERRROR:          8.9287
# INFO:main:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 347.39it/s]
# INFO:main:  True Entropy:    5.5635
# INFO:main:  Final Estimate:  18.5622
# INFO:main:  ERRROR:          12.9986
# INFO:main:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 429.06it/s]
# INFO:main:  True Entropy:    5.5635
# INFO:main:  Final Estimate:  18.3521
# INFO:main:  ERRROR:          12.7886
# INFO:main:FINAL:
# INFO:main:KNIFE:
# INFO:main:  error 1: 11.2400 ± 2.3113
# INFO:main:Schraudolph:
# INFO:main:  error 1: 15.2070 ± 2.2084
# INFO:main:DoE:
# INFO:main:  error 1: 16.8468 ± 4.0582
