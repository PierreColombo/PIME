# %%
from benchmarking_differencial_entropy_estimators import meta_main, get_args
from tools import plot_entropy, plot_pdf
from os.path import join
import sys

# %% [markdown]
# ### First two experiments for $d=10,64$ in Section 3.1.1

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 1
args.iterations = 200
args.pdf = 'gaussian'
args.dimension = 10
args.reps = 3
args.lr = 1e-2

meta_main(args)
# Out:
# INFO:benchmarking_differencial_entropy_estimators:Doing run 1...
# INFO:benchmarking_differencial_entropy_estimators:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       200
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:benchmarking_differencial_entropy_estimators:Epoch 1/1 starting ...
# 100%|██████████| 200/200 [00:03<00:00, 51.83it/s]
# INFO:benchmarking_differencial_entropy_estimators:Finished training.
# INFO:benchmarking_differencial_entropy_estimators:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 73.29it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.2345
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.0451
# INFO:benchmarking_differencial_entropy_estimators:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 88.62it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.8855
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.6961
# INFO:benchmarking_differencial_entropy_estimators:DoE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 87.91it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.5280
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.3386
# INFO:benchmarking_differencial_entropy_estimators:Doing run 2...
# INFO:benchmarking_differencial_entropy_estimators:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       200
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:benchmarking_differencial_entropy_estimators:Epoch 1/1 starting ...
# 100%|██████████| 200/200 [00:03<00:00, 55.28it/s]
# INFO:benchmarking_differencial_entropy_estimators:Finished training.
# INFO:benchmarking_differencial_entropy_estimators:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 78.72it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.2435
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.0542
# INFO:benchmarking_differencial_entropy_estimators:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 86.31it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.8829
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.6935
# INFO:benchmarking_differencial_entropy_estimators:DoE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 92.92it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.7227
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.5333
# INFO:benchmarking_differencial_entropy_estimators:Doing run 3...
# INFO:benchmarking_differencial_entropy_estimators:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           3
#       batchsize:        128
#       iterations:       200
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:benchmarking_differencial_entropy_estimators:Epoch 1/1 starting ...
# 100%|██████████| 200/200 [00:03<00:00, 57.31it/s]
# INFO:benchmarking_differencial_entropy_estimators:Finished training.
# INFO:benchmarking_differencial_entropy_estimators:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 81.92it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.2450
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.0556
# INFO:benchmarking_differencial_entropy_estimators:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 87.95it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.8908
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.7014
# INFO:benchmarking_differencial_entropy_estimators:DoE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:02<00:00, 96.39it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    14.1894
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  14.6393
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.4499
# INFO:benchmarking_differencial_entropy_estimators:FINAL:
# INFO:benchmarking_differencial_entropy_estimators:KNIFE:
# INFO:benchmarking_differencial_entropy_estimators:  error 1: 0.0516 ± 0.0047
# INFO:benchmarking_differencial_entropy_estimators:Schraudolph:
# INFO:benchmarking_differencial_entropy_estimators:  error 1: 0.6970 ± 0.0033
# INFO:benchmarking_differencial_entropy_estimators:DoE:
# INFO:benchmarking_differencial_entropy_estimators:  error 1: 0.4406 ± 0.0797
# 'runs/pdf-gaussian/cubic-False/d-10/rho-1.00'

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 1
args.iterations = 200
args.pdf = 'gaussian'
args.dimension = 64
args.reps = 3
args.lr = 1e-2

meta_main(args)
# Out:
# INFO:benchmarking_differencial_entropy_estimators:Doing run 1...
# INFO:benchmarking_differencial_entropy_estimators:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-64/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       200
#       epochs:           1
#       kernel_samples:   128
#       d:                64
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:benchmarking_differencial_entropy_estimators:Epoch 1/1 starting ...
#  58%|█████▊    | 117/200 [00:32<00:21,  3.88it/s][E thread_pool.cpp:113] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:113] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:113] Exception in thread pool task: mutex lock failed: Invalid argument
#  58%|█████▊    | 117/200 [00:32<00:23,  3.59it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/49/yzllcjl93rbc47nkmb2kb9z80000gp/T/ipykernel_7894/2018308668.py in <module>
#       9 args.lr = 1e-2
#      10
# ---> 11 meta_main(args)
#
# ~/Desktop/PIME/examples/benchmarking_differencial_entropy_estimators.py in meta_main(args)
#     338             if args.reps > 1:
#     339                 args.run_id = i + 1
# --> 340             outputs = {k: np.array([v]) for k, v in main(args).items()}
#     341             for name, value in outputs.items():
#     342                 if name not in all_outputs:
#
# ~/Desktop/PIME/examples/benchmarking_differencial_entropy_estimators.py in main(args)
#     209                 for model, opt, name in zip(models, opts, model_names):
#     210                     loss_adaptive = model(x)
# --> 211                     loss_adaptive.backward()
#     212                     loss_np = loss_adaptive.detach().cpu().numpy()
#     213                     error_np = loss_np - true_entropy
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ### Experiment depicted in Figure 1

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 16 #128
args.epochs = 5
args.iterations = 1000
args.pdf = 'gaussian'
args.dimension = 16 #64
args.rho = 0.5
args.rho_steps = 5
args.reps = 1
args.lr = 1e-2
args.run_id = 1

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
# Out:
# INFO:benchmarking_differencial_entropy_estimators:Doing run 1...
# INFO:benchmarking_differencial_entropy_estimators:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-16/rho-0.50
#       run_id:           1
#       batchsize:        128
#       iterations:       1000
#       epochs:           5
#       kernel_samples:   16
#       d:                16
#       pdf:              gaussian
#       rho:              0.50
#       lr:               0.01
#
# INFO:benchmarking_differencial_entropy_estimators:Epoch 1/5 starting ...
# 100%|██████████| 1000/1000 [00:07<00:00, 134.72it/s]
# INFO:benchmarking_differencial_entropy_estimators:Epoch 2/5 starting ...
# 100%|██████████| 1000/1000 [00:06<00:00, 143.69it/s]
# INFO:benchmarking_differencial_entropy_estimators:Epoch 3/5 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 107.13it/s]
# INFO:benchmarking_differencial_entropy_estimators:Epoch 4/5 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 109.24it/s]
# INFO:benchmarking_differencial_entropy_estimators:Epoch 5/5 starting ...
# 100%|██████████| 1000/1000 [00:09<00:00, 107.11it/s]
# INFO:benchmarking_differencial_entropy_estimators:Finished training.
# INFO:benchmarking_differencial_entropy_estimators:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:03<00:00, 320.65it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    0.5223
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  0.5684
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.0461
# INFO:benchmarking_differencial_entropy_estimators:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 384.39it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    0.5223
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  12.9512
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          12.4289
# INFO:benchmarking_differencial_entropy_estimators:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:02<00:00, 396.81it/s]
# INFO:benchmarking_differencial_entropy_estimators:  True Entropy:    0.5223
# INFO:benchmarking_differencial_entropy_estimators:  Final Estimate:  0.5375
# INFO:benchmarking_differencial_entropy_estimators:  ERRROR:          0.0151
# INFO:benchmarking_differencial_entropy_estimators:FINAL:
# INFO:benchmarking_differencial_entropy_estimators:KNIFE:
# INFO:benchmarking_differencial_entropy_estimators:  error 1: 0.0461 ± 0.0000
# INFO:benchmarking_differencial_entropy_estimators:Schraudolph:
# INFO:benchmarking_differencial_entropy_estimators:  error 1: 12.4289 ± 0.0000
# INFO:benchmarking_differencial_entropy_estimators:DoE:
# INFO:benchmarking_differencial_entropy_estimators:  error 1: 0.0151 ± 0.0000

# %% [markdown]
# ### Experiment depicted in Figure 2(left)

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 10
args.iterations = 200
args.pdf = 'triangle'
args.dimension = 1
args.plot = True
args.data_components = 10
args.lr = 1e-1
args.run_id = 1

log_dir = meta_main(args)
plot_pdf(join(log_dir, '1', 'pdfs_KNIFE_0.json'), show=True)

# %% [markdown]
# ### Experiment depicted in Figure 2(right)

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 20
args.iterations = 1000
args.pdf = 'triangle'
args.dimension = 8
args.data_components = 2
args.lr = 1e-3
args.reps = 3

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)

# %% [markdown]
# ### Experiment in supplementary material, B.2

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 20
args.iterations = 1000
args.pdf = 'triangle'
args.dimension = 20
args.data_components = 2
args.lr = 1e-3
args.reps = 10

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
